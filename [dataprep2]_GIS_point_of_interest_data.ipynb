# %% [markdown]
# <a href="https://colab.research.google.com/github/sujiraa/bsc_dpdm22/blob/main/%5Bdataprep2%5D_GIS_point_of_interest_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/MyDrive/databsc/7-eleven.json') as json_file: #เปิดไฟล์ json
    this_json = json.loads(json_file.read())

# %%
this_json.keys() #

# %%
len(this_json)
# Out:
# 3653

# %%
this_json['1'] #ไม่มีค่า
# Out:
# []

# %%
this_json['6']

# %%
seven_id = {}
for t in this_json:
    l = list()
    for x in this_json[t]:
        l.append(x['geometry']['location'])
    print(t) #ดึงไอดี (t)
    print(l)
    seven_id[t] = l
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# 6284
# []
# 6285
# [{'lat': 16.3280289, 'lng': 102.8466104}]
# 6286
# []
# 6289
# []
# 6290
# []
# 6291
# [{'lat': 16.760925, 'lng': 102.6348166}]
# 6292
# [{'lat': 16.3280289, 'lng': 102.8466104}]
# 6296
# [{'lat': 16.5219606, 'lng': 102.219816}]
# 6297
# []
# 6298
# [{'lat': 16.4501543, 'lng': 102.7382279}, {'lat': 16.4481776, 'lng': 102.7736213}, {'lat': 16.4496233, 'lng': 102.7578029}, {'lat': 16.4512684, 'lng': 102.7517798}]
# 6302
# []
# 6306
# []
# 6310
# []
# 6311
# []
# 6313
# [{'lat': 16.4506978, 'lng': 102.7955315}, {'lat': 16.4786388, 'lng': 102.814293}, {'lat': 16.4794698, 'lng': 102.8070934}, {'lat': 16.4423, 'lng': 102.808299}, {'lat': 16.4802561, 'lng': 102.8118345}, {'lat': 16.4800345, 'lng': 102.817991}, {'lat': 16.4800801, 'lng': 102.8157501}, {'lat': 16.4421359, 'lng': 102.8198991}, {'lat': 16.4781927, 'lng': 102.8199828}, {'lat': 16.4463944, 'lng': 102.8200097}]
# 6316
# []
# 6319
# ...

# %%
seven_id
# Out:
# {'1': [],
#  '4': [],
#  '6': [{'lat': 16.0603149, 'lng': 102.7264856},
#   {'lat': 16.0564741, 'lng': 102.7268436},
#   {'lat': 16.0595413, 'lng': 102.7294307},
#   {'lat': 16.0751998, 'lng': 102.7356017},
#   {'lat': 16.070648, 'lng': 102.7344055},
#   {'lat': 16.0582995, 'lng': 102.7360953},
#   {'lat': 16.0573901, 'lng': 102.7192322}],
#  '7': [],
#  '9': [],
#  '11': [{'lat': 15.809535, 'lng': 102.6069684},
#   {'lat': 15.8193062, 'lng': 102.6012589},
#   {'lat': 15.8125848, 'lng': 102.6009202},
#   {'lat': 15.8102763, 'lng': 102.5985417},
#   {'lat': 15.8095537, 'lng': 102.5879272},
#   {'lat': 15.7970035, 'lng': 102.6075296}],
#  '16': [{'lat': 16.1340329, 'lng': 102.5331697},
#   {'lat': 16.1294298, 'lng': 102.540669}],
#  '17': [{'lat': 16.4052438, 'lng': 102.7823961},
#   {'lat': 16.3898169, 'lng': 102.8053144},
#   {'lat': 16.4221806, 'lng': 102.8047853},
#   {'lat': 16.4083692, 'lng': 102.7948258},
#   {'lat': 16.4053255, 'lng': 102.7746538}],
# ...

# %%
c = list()
for row in this_json["6"]:
    c.append(row["geometry"]["location"])

# %%
c
# Out:
# [{'lat': 16.0603149, 'lng': 102.7264856},
#  {'lat': 16.0564741, 'lng': 102.7268436},
#  {'lat': 16.0595413, 'lng': 102.7294307},
#  {'lat': 16.0751998, 'lng': 102.7356017},
#  {'lat': 16.070648, 'lng': 102.7344055},
#  {'lat': 16.0582995, 'lng': 102.7360953},
#  {'lat': 16.0573901, 'lng': 102.7192322}]

# %%
this_json['6']

# %% [markdown]
# #load Data = home

# %%
home = pd.read_excel('/content/drive/MyDrive/databsc/Data Supply.xlsx')
home
# Out:
#     post_id       https://nayoo.co/khonkaen/posts/  type   post_type  \
# 0      25.0     https://nayoo.co/khonkaen/posts/25  post  secondhand
# 1      33.0     https://nayoo.co/khonkaen/posts/33  post  secondhand
# 2     495.0    https://nayoo.co/khonkaen/posts/495  post  secondhand
# 3     564.0    https://nayoo.co/khonkaen/posts/564  post  secondhand
# 4     566.0    https://nayoo.co/khonkaen/posts/566  post  secondhand
# ..      ...                                    ...   ...         ...
# 95  19495.0  https://nayoo.co/khonkaen/posts/19495  post  secondhand
# 96  19496.0  https://nayoo.co/khonkaen/posts/19496  post  secondhand
# 97  20164.0  https://nayoo.co/khonkaen/posts/20164  post  secondhand
# 98     31.0     https://nayoo.co/khonkaen/posts/31  post  secondhand
# 99    570.0    https://nayoo.co/khonkaen/posts/570  post  secondhand
#
#    listing_type  parent_id  draft_for          project_name  \
# 0          sale        NaN        NaN  กันยารัตน์ เดอวินเทจ
# ...

# %%
this_seven = seven_id['25']
this_seven
# Out:
# [{'lat': 16.4229267, 'lng': 102.8712313},
#  {'lat': 16.4255945, 'lng': 102.8397278},
#  {'lat': 16.4251666, 'lng': 102.8510168},
#  {'lat': 16.4075683, 'lng': 102.8597974},
#  {'lat': 16.4198307, 'lng': 102.8496996},
#  {'lat': 16.4236724, 'lng': 102.8434961},
#  {'lat': 16.4059038, 'lng': 102.839094},
#  {'lat': 16.4276489, 'lng': 102.867949},
#  {'lat': 16.4276748, 'lng': 102.8632914},
#  {'lat': 16.4285371, 'lng': 102.8496085},
#  {'lat': 16.4187106, 'lng': 102.8405019},
#  {'lat': 16.4289683, 'lng': 102.8471979},
#  {'lat': 16.4288908, 'lng': 102.8559018},
#  {'lat': 16.4288377, 'lng': 102.8542497},
#  {'lat': 16.3990089, 'lng': 102.8381851},
#  {'lat': 16.4289572, 'lng': 102.8477644},
#  {'lat': 16.4268631, 'lng': 102.8371875}]

# %%
home[home['post_id']==25]
# Out:
#    post_id    https://nayoo.co/khonkaen/posts/  type   post_type listing_type  \
# 0     25.0  https://nayoo.co/khonkaen/posts/25  post  secondhand         sale
#
#    parent_id  draft_for          project_name  \
# 0        NaN        NaN  กันยารัตน์ เดอวินเทจ
#
#                             contact_name  province_id  ...  cable_max  \
# 0  บริษัท กันยารัตน์ พร็อพเพอร์ตี้ จำกัด          6.0  ...        NaN
#
#   cable_free  cable_none cable_ask position_previous  position_current  \
# 0        NaN         NaN       NaN             991.0             991.0
#
#   sold_out_at          created_at          updated_at  deleted_at
# 0         NaT 2020-06-29 06:25:32 2021-10-10 15:58:05         NaN
#
# [1 rows x 183 columns]

# %%
this_home['latitude'][0]

# %%
this_home['longitude][0]

# %%
this_seven[0]

# %%
this_seven[0['lat']]

# %%
import geopy.distance

# %% [markdown]
# #HW4 สร้างตาราง
