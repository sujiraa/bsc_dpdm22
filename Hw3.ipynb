# %% [markdown]
# <a href="https://colab.research.google.com/github/sujiraa/bsc_dpdm22/blob/main/Hw3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##HW3
#  visualize แสดงความสัมพันธ์ ราคา(ตั้งขายและประเมิน)-ความมั่นใจ-ให้คะแนนทรัพย์

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
sheet_id = '13tZJ1ZQuO6HWzbuZzabmmF_NnZpLAw2TG_eqN_ExU3U'
sheet_name = 'home'
url1 = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
sheet_id = '13tZJ1ZQuO6HWzbuZzabmmF_NnZpLAw2TG_eqN_ExU3U'
sheet_name = 'land'
url2 = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
sheet_id = '13tZJ1ZQuO6HWzbuZzabmmF_NnZpLAw2TG_eqN_ExU3U'
sheet_name = 'townhome'
url3 = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
sheet_id = '13tZJ1ZQuO6HWzbuZzabmmF_NnZpLAw2TG_eqN_ExU3U'
sheet_name = 'commercial'
url4 = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
data1 = pd.read_csv(url1)
data2 = pd.read_csv(url2)
data3 = pd.read_csv(url3)
data4 = pd.read_csv(url4)

# %%
townhome1 = data3[['post id', 'property_type',
       'ความมั่นใจในการเมินราคาทรัพย์', 'ราคาทรัพย์', 'ประเมินราคาซื้อ-ขาย',
       'ปัจจัยในการประเมินราคาซื้อ-ขาย',
       'ให้คะแนนทรัพย์']]

# %%
home1 = data1[['post id', 'property_type',
       'ความมั่นใจในการเมินราคาทรัพย์', 'ราคาทรัพย์', 'ประเมินราคาซื้อ-ขาย',
       'ปัจจัยในการประเมินราคาซื้อ-ขาย',
       'ให้คะแนนทรัพย์']]

# %%
land1 = data2[['post id', 'property_type',
       'ความมั่นใจในการเมินราคาทรัพย์', 'ราคาทรัพย์', 'ประเมินราคาซื้อ-ขาย',
       'ปัจจัยในการประเมินราคาซื้อ-ขาย',
       'ให้คะแนนทรัพย์']]

# %%
commercial1 = data4[['post id', 'property_type',
       'ความมั่นใจในการเมินราคาทรัพย์', 'ราคาทรัพย์', 'ประเมินราคาซื้อ-ขาย',
       'ปัจจัยในการประเมินราคาซื้อ-ขาย',
       'ให้คะแนนทรัพย์']]

# %%
homeC = home1.dropna(subset=['ประเมินราคาซื้อ-ขาย','ปัจจัยในการประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์'])

# %%
landC = land1.dropna(subset=['ประเมินราคาซื้อ-ขาย','ปัจจัยในการประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์'])

# %%
commercialC = commercial1.dropna(subset=['ประเมินราคาซื้อ-ขาย','ปัจจัยในการประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์'])

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=[20,20]

# %%
plt.subplot(2,4,1)
townhome1["ราคาทรัพย์"].plot();
townhome1["ประเมินราคาซื้อ-ขาย"].plot(secondary_y=True, style="g");
plt.title('townhome price');

plt.subplot(2,4,2)
plt.hist([townhome1['ความมั่นใจในการเมินราคาทรัพย์']])
plt.hist([townhome1['ให้คะแนนทรัพย์']])
plt.xticks(rotation='vertical');
plt.title('townhome score');

plt.subplot(2,4,3)
homeC["ราคาทรัพย์"].plot();
homeC["ประเมินราคาซื้อ-ขาย"].plot(secondary_y=True, style="g");
plt.title('home price');

plt.subplot(2,4,4)
plt.hist([homeC['ความมั่นใจในการเมินราคาทรัพย์']])
plt.hist([homeC['ให้คะแนนทรัพย์']])
plt.xticks(rotation='vertical');
plt.title('home score');

plt.subplot(2,4,5)
landC["ราคาทรัพย์"].plot();
landC["ประเมินราคาซื้อ-ขาย"].plot(secondary_y=True, style="g");
plt.title('land price');

plt.subplot(2,4,6)
plt.hist([landC['ความมั่นใจในการเมินราคาทรัพย์']])
plt.hist([landC['ให้คะแนนทรัพย์']])
plt.xticks(rotation='vertical');
plt.title('land score');

plt.subplot(2,4,7)
commercialC["ราคาทรัพย์"].plot();
commercialC["ประเมินราคาซื้อ-ขาย"].plot(secondary_y=True, style="g");
plt.title('commercial price');

plt.subplot(2,4,8)
plt.hist([commercialC['ความมั่นใจในการเมินราคาทรัพย์']])
plt.hist([commercialC['ให้คะแนนทรัพย์']])
plt.xticks(rotation='vertical');
plt.title('commercial1 score');

# %%
series = pd.Series(3 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")

series.plot.pie(figsize=(6, 6));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0699105aea03> in <module>
# ----> 1 series = pd.Series(3 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")
#       2
#       3 series.plot.pie(figsize=(6, 6));
#
# NameError: name 'np' is not defined
